# %% [markdown]
# # Exploratory data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv('data_clean.csv')
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     2    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5             6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6             7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7             8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8             9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9            10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10           11    7.0      NaN   6.9      C     5   11  2010    74       C
# ...

# %%
df = pd.read_csv('data_clean.csv',index_col=0)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1   41.0    190.0   7.4     67     2    1  2010    67       S
# 2   36.0    118.0   8.0     72     5    2  2010    72       C
# 3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 4   18.0    313.0  11.5     62     5    4  2010    62       S
# 5    NaN      NaN  14.3     56     5    5  2010    56       S

# %% [markdown]
# ### information about the data

# %%
df.shape # gives rows n cols
# Out:
# (158, 9)

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp C', 'Month', 'Day', 'Year', 'Temp',
#        'Weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
df.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
pd.to_numeric(df['Month'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "May"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 pd.to_numeric(df['Month'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
df.Month = pd.to_numeric(df.Month,errors='coerce')

# %%
df.Month[21:25]
# Out:
# 22    5.0
# 23    5.0
# 24    NaN
# 25    5.0
# Name: Month, dtype: float64

# %%
pd.to_numeric(df['Temp C'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "C"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 pd.to_numeric(df['Temp C'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
df['Temp C']=pd.to_numeric(df['Temp C'],errors='coerce')

# %%
df['Temp C'][10:12]
# Out:
# 11     NaN
# 12    69.0
# Name: Temp C, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 12.3+ KB

# %%
df['Weather'].astype(str)
# Out:
# 1        S
# 2        C
# 3       PS
# 4        S
# 5        S
# 6        C
# 7       PS
# 8        C
# 9       PS
# 10       S
# 11       C
# 12      PS
# 13       S
# 14       S
# 15       C
# 16       S
# 17       S
# 18       C
# 19      PS
# 20       S
# 21       S
# 22       C
# 23      PS
# 24       C
# 25      PS
# 26       C
# 27      PS
# 28       S
# 29       S
# 30       C
# 31      PS
# 32       S
# 33       C
# 34      PS
# 35       C
# 36      PS
# 37       C
# 38      PS
# 39       S
# 40       S
# 41       S
# 42       C
# 43      PS
# 44       S
# 45       S
# 46       C
# 47      PS
# 48       C
# 49      PS
# 50       S
# 51       S
# 52       S
# 53       C
# 54      PS
# 55       S
# 56       C
# 57      PS
# 58       C
# 59      PS
# 60       S
# 61       S
# 62       S
# 63       C
# 64      PS
# 65       S
# 66       S
# 67       C
# 68       C
# 69      PS
# 70       C
# 71      PS
# 72       S
# 73       S
# 74       S
# 75       C
# 76      PS
# ...

# %%
df['Weather'].astype('object')
# Out:
# 1        S
# 2        C
# 3       PS
# 4        S
# 5        S
# 6        C
# 7       PS
# 8        C
# 9       PS
# 10       S
# 11       C
# 12      PS
# 13       S
# 14       S
# 15       C
# 16       S
# 17       S
# 18       C
# 19      PS
# 20       S
# 21       S
# 22       C
# 23      PS
# 24       C
# 25      PS
# 26       C
# 27      PS
# 28       S
# 29       S
# 30       C
# 31      PS
# 32       S
# 33       C
# 34      PS
# 35       C
# 36      PS
# 37       C
# 38      PS
# 39       S
# 40       S
# 41       S
# 42       C
# 43      PS
# 44       S
# 45       S
# 46       C
# 47      PS
# 48       C
# 49      PS
# 50       S
# 51       S
# 52       S
# 53       C
# 54      PS
# 55       S
# 56       C
# 57      PS
# 58       C
# 59      PS
# 60       S
# 61       S
# 62       S
# 63       C
# 64      PS
# 65       S
# 66       S
# 67       C
# 68       C
# 69      PS
# 70       C
# 71      PS
# 72       S
# 73       S
# 74       S
# 75       C
# 76      PS
# ...

# %%
df['Weather'] = df['Weather'].astype('category')

# %%
df['Day'] = df['Day'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int32
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int32(1), int64(2)
# memory usage: 10.8 KB

# %%
df['Weather'] = df['Weather'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int32
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(5), int32(1), int64(2), object(1)
# memory usage: 11.7+ KB

# %%
df.drop('Year',axis = 1,inplace  = True)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 1   41.0    190.0   7.4    67.0    2.0    1    67       S
# 2   36.0    118.0   8.0    72.0    5.0    2    72       C
# 3   12.0    149.0  12.6    74.0    5.0    3    74      PS
# 4   18.0    313.0  11.5    62.0    5.0    4    62       S
# 5    NaN      NaN  14.3    56.0    5.0    5    56       S

# %%
df.drop('Temp C',axis = 1,inplace=True)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 1   41.0    190.0   7.4    2.0    1    67       S
# 2   36.0    118.0   8.0    5.0    2    72       C
# 3   12.0    149.0  12.6    5.0    3    74      PS
# 4   18.0    313.0  11.5    5.0    4    62       S
# 5    NaN      NaN  14.3    5.0    5    56       S

# %%
df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
df[df.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 157   14.0    191.0  14.3    9.0   28    75       S

# %%
df[df.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 151   14.0    191.0  14.3    9.0   28    75       S
# 157   14.0    191.0  14.3    9.0   28    75       S

# %%
df.drop_duplicates(inplace=True)

# %%
df.tail(10)
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 148   14.0     20.0  16.6    9.0   25    63      PS
# 149   30.0    193.0   6.9    9.0   26    70       C
# 150    NaN    145.0  13.2    9.0   27    77      PS
# 151   14.0    191.0  14.3    9.0   28    75       S
# 152   18.0    131.0   8.0    9.0   29    76      PS
# 153   20.0    223.0  11.5    9.0   30    68       S
# 154   41.0    190.0   7.4    5.0    1    67       C
# 155   30.0    193.0   6.9    9.0   26    70      PS
# 156    NaN    145.0  13.2    9.0   27    77       S
# 158   18.0    131.0   8.0    9.0   29    76       C

# %%
df.rename({'Solar.R':'Solar'},axis =1,inplace=True)

# %%
df.rename({1:"a"})
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# a     41.0  190.0   7.4    2.0    1    67       S
# 2     36.0  118.0   8.0    5.0    2    72       C
# 3     12.0  149.0  12.6    5.0    3    74      PS
# 4     18.0  313.0  11.5    5.0    4    62       S
# 5      NaN    NaN  14.3    5.0    5    56       S
# 6     28.0    NaN  14.9    5.0    6    66       C
# 7     23.0  299.0   8.6    5.0    7    65      PS
# 8     19.0   99.0  13.8    5.0    8    59       C
# 9      8.0   19.0  20.1    5.0    9    61      PS
# 10     NaN  194.0   8.6    5.0   10    69       S
# 11     7.0    NaN   6.9    5.0   11    74       C
# 12    16.0  256.0   9.7    5.0   12    69      PS
# 13    11.0  290.0   9.2    5.0   13    66       S
# 14    14.0  274.0  10.9    5.0   14    68       S
# 15    18.0   65.0  13.2    5.0   15    58       C
# 16    14.0  334.0  11.5    5.0   16    64       S
# 17    34.0  307.0  12.0    5.0   17    66       S
# 18     6.0   78.0  18.4    5.0   18    57       C
# ...

# %%
df
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 1     41.0  190.0   7.4    2.0    1    67       S
# 2     36.0  118.0   8.0    5.0    2    72       C
# 3     12.0  149.0  12.6    5.0    3    74      PS
# 4     18.0  313.0  11.5    5.0    4    62       S
# 5      NaN    NaN  14.3    5.0    5    56       S
# 6     28.0    NaN  14.9    5.0    6    66       C
# 7     23.0  299.0   8.6    5.0    7    65      PS
# 8     19.0   99.0  13.8    5.0    8    59       C
# 9      8.0   19.0  20.1    5.0    9    61      PS
# 10     NaN  194.0   8.6    5.0   10    69       S
# 11     7.0    NaN   6.9    5.0   11    74       C
# 12    16.0  256.0   9.7    5.0   12    69      PS
# 13    11.0  290.0   9.2    5.0   13    66       S
# 14    14.0  274.0  10.9    5.0   14    68       S
# 15    18.0   65.0  13.2    5.0   15    58       C
# 16    14.0  334.0  11.5    5.0   16    64       S
# 17    34.0  307.0  12.0    5.0   17    66       S
# 18     6.0   78.0  18.4    5.0   18    57       C
# ...

# %%
df.reset_index(drop = True,inplace=True)

# %%
df
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 0     41.0  190.0   7.4    2.0    1    67       S
# 1     36.0  118.0   8.0    5.0    2    72       C
# 2     12.0  149.0  12.6    5.0    3    74      PS
# 3     18.0  313.0  11.5    5.0    4    62       S
# 4      NaN    NaN  14.3    5.0    5    56       S
# 5     28.0    NaN  14.9    5.0    6    66       C
# 6     23.0  299.0   8.6    5.0    7    65      PS
# 7     19.0   99.0  13.8    5.0    8    59       C
# 8      8.0   19.0  20.1    5.0    9    61      PS
# 9      NaN  194.0   8.6    5.0   10    69       S
# 10     7.0    NaN   6.9    5.0   11    74       C
# 11    16.0  256.0   9.7    5.0   12    69      PS
# 12    11.0  290.0   9.2    5.0   13    66       S
# 13    14.0  274.0  10.9    5.0   14    68       S
# 14    18.0   65.0  13.2    5.0   15    58       C
# 15    14.0  334.0  11.5    5.0   16    64       S
# 16    34.0  307.0  12.0    5.0   17    66       S
# 17     6.0   78.0  18.4    5.0   18    57       C
# ...

# %%
df.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Temp Weather
# 0   41.0  190.0   7.4    2.0    1    67       S
# 1   36.0  118.0   8.0    5.0    2    72       C
# 2   12.0  149.0  12.6    5.0    3    74      PS
# 3   18.0  313.0  11.5    5.0    4    62       S
# 4    NaN    NaN  14.3    5.0    5    56       S

# %% [markdown]
# # Outliers

# %%
import seaborn as sns

# %%
df.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day        Temp
# count  119.000000  150.000000  157.000000  156.000000  157.000000  157.000000
# mean    41.815126  185.366667    9.929936    7.012821   15.929936   77.745223
# std     32.659249   89.019146    3.505188    1.476645    8.974404    9.405334
# min      1.000000    7.000000    1.700000    2.000000    1.000000   56.000000
# 25%     18.000000  118.500000    7.400000    6.000000    8.000000   72.000000
# 50%     31.000000  199.000000    9.700000    7.000000   16.000000   79.000000
# 75%     62.000000  257.500000   11.500000    8.000000   24.000000   84.000000
# max    168.000000  334.000000   20.700000    9.000000   31.000000   97.000000

# %%
sns.pairplot(df);

# %%
df.hist('Ozone');

# %%
sns.histplot(df['Ozone'])
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Count'>

# %%
df.Ozone.skew()
# Out:
# 1.2720131447501268

# %%
df.boxplot('Ozone')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(y = df.Ozone)
# Out:
# <AxesSubplot:ylabel='Ozone'>

# %%
box = plt.boxplot(df.Ozone.dropna())

# %%
[i.get_ydata() for i in box['fliers']]
# Out:
# [array([135., 168.])]

# %% [markdown]
# # 3. Treatment of Outliers

# %%
# kill (filter method)

# %%
df.shape
# Out:
# (157, 7)

# %%
df.Ozone.isnull().sum()
# Out:
# 38

# %%
df2 = df[df['Ozone']<=134]

# %%
df2.Ozone
# Out:
# 0       41.0
# 1       36.0
# 2       12.0
# 3       18.0
# 5       28.0
# 6       23.0
# 7       19.0
# 8        8.0
# 10       7.0
# 11      16.0
# 12      11.0
# 13      14.0
# 14      18.0
# 15      14.0
# 16      34.0
# 17       6.0
# 18      30.0
# 19      11.0
# 20       1.0
# 21      11.0
# 22       4.0
# 23      32.0
# 27      23.0
# 28      45.0
# 29     115.0
# 30      37.0
# 37      29.0
# 39      71.0
# 40      39.0
# 43      23.0
# 46      21.0
# 47      37.0
# 48      20.0
# 49      12.0
# 50      13.0
# 62      49.0
# 63      32.0
# 65      64.0
# 66      40.0
# 67      77.0
# 68      97.0
# 69      97.0
# 70      85.0
# 72      10.0
# 73      27.0
# 75       7.0
# 76      48.0
# 77      35.0
# 78      61.0
# 79      79.0
# 80      63.0
# 81      16.0
# 84      80.0
# 85     108.0
# 86      20.0
# 87      52.0
# 88      82.0
# 89      50.0
# 90      64.0
# 91      59.0
# 92      39.0
# 93       9.0
# 94      16.0
# 95      78.0
# 96      35.0
# 97      66.0
# ...

# %%
box2 = plt.boxplot(df2.Ozone)

# %%
[i.get_ydata()  for i in box2['fliers']]
# Out:
# [array([122.])]

# %%
q3= df2['Ozone'].quantile(0.75)

# %%
q3
# Out:
# 59.0

# %%
q1= df2['Ozone'].quantile(0.25)

# %%
q1
# Out:
# 18.0

# %%
q3 + 1.5*(q3 - q1)
# Out:
# 120.5

# %%
df2.shape
# Out:
# (117, 7)

# %% [markdown]
# # treatment of outliers (Winsorization)

# %%
from scipy.stats.mstats import winsorize

# %%
array3 = winsorize(df.Ozone.dropna(),(0.05,0.05))

# %%
array3
# Out:
# masked_array(data=[ 41.,  36.,  12.,  18.,  28.,  23.,  19.,   8.,   7.,
#                     16.,  11.,  14.,  18.,  14.,  34.,   7.,  30.,  11.,
#                      7.,  11.,   7.,  32.,  23.,  45., 110.,  37.,  29.,
#                     71.,  39.,  23.,  21.,  37.,  20.,  12.,  13., 110.,
#                     49.,  32.,  64.,  40.,  77.,  97.,  97.,  85.,  10.,
#                     27.,   7.,  48.,  35.,  61.,  79.,  63.,  16.,  80.,
#                    108.,  20.,  52.,  82.,  50.,  64.,  59.,  39.,   9.,
#                     16.,  78.,  35.,  66., 110.,  89., 110.,  44.,  28.,
#                     65.,  22.,  59.,  23.,  31.,  44.,  21.,   9.,  45.,
#                    110.,  73.,  76., 110.,  84.,  85.,  96.,  78.,  73.,
#                     91.,  47.,  32.,  20.,  23.,  21.,  24.,  44.,  21.,
#                     28.,   9.,  13.,  46.,  18.,  13.,  24.,  16.,  13.,
#                     23.,  36.,   7.,  14.,  30.,  14.,  18.,  20.,  41.,
# ...

# %%
df.Ozone.dropna().quantile(0.95)
# Out:
# 108.19999999999999

# %%
plt.boxplot(array3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13d2e74ce80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13d2e5d85e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13d2e74caf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13d2e5d8d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13d2e5e70d0>],
#  'means': []}

# %% [markdown]
# # 4. Missing values

# %%
df
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 0     41.0  190.0   7.4    2.0    1    67       S
# 1     36.0  118.0   8.0    5.0    2    72       C
# 2     12.0  149.0  12.6    5.0    3    74      PS
# 3     18.0  313.0  11.5    5.0    4    62       S
# 4      NaN    NaN  14.3    5.0    5    56       S
# 5     28.0    NaN  14.9    5.0    6    66       C
# 6     23.0  299.0   8.6    5.0    7    65      PS
# 7     19.0   99.0  13.8    5.0    8    59       C
# 8      8.0   19.0  20.1    5.0    9    61      PS
# 9      NaN  194.0   8.6    5.0   10    69       S
# 10     7.0    NaN   6.9    5.0   11    74       C
# 11    16.0  256.0   9.7    5.0   12    69      PS
# 12    11.0  290.0   9.2    5.0   13    66       S
# 13    14.0  274.0  10.9    5.0   14    68       S
# 14    18.0   65.0  13.2    5.0   15    58       C
# 15    14.0  334.0  11.5    5.0   16    64       S
# 16    34.0  307.0  12.0    5.0   17    66       S
# 17     6.0   78.0  18.4    5.0   18    57       C
# ...

# %%
# detection of missing values
# 1) info()
# 2).isnull().sum()
#3) heatmap
#4) .notnull().sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int32
#  5   Temp     157 non-null    int64
#  6   Weather  154 non-null    object
# dtypes: float64(4), int32(1), int64(1), object(1)
# memory usage: 8.1+ KB

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Temp        0
# Weather     3
# dtype: int64

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# Ozone      24.203822
# Solar       4.458599
# Wind        0.000000
# Month       0.636943
# Day         0.000000
# Temp        0.000000
# Weather     1.910828
# dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.isnull(),cmap = sns.color_palette(palette='BuGn'))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.isnull(),cmap = sns.color_palette(palette=['black','white']))
# Out:
# <AxesSubplot:>

# %%
df.notnull().sum()
# Out:
# Ozone      119
# Solar      150
# Wind       157
# Month      156
# Day        157
# Temp       157
# Weather    154
# dtype: int64

# %% [markdown]
# # 5.Treatment of missing values

# %%
# kill

#dropna()

# %%
df.shape
# Out:
# (157, 7)

# %%
df.dropna(axis = 0)
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 0     41.0  190.0   7.4    2.0    1    67       S
# 1     36.0  118.0   8.0    5.0    2    72       C
# 2     12.0  149.0  12.6    5.0    3    74      PS
# 3     18.0  313.0  11.5    5.0    4    62       S
# 6     23.0  299.0   8.6    5.0    7    65      PS
# 7     19.0   99.0  13.8    5.0    8    59       C
# 8      8.0   19.0  20.1    5.0    9    61      PS
# 11    16.0  256.0   9.7    5.0   12    69      PS
# 12    11.0  290.0   9.2    5.0   13    66       S
# 13    14.0  274.0  10.9    5.0   14    68       S
# 14    18.0   65.0  13.2    5.0   15    58       C
# 15    14.0  334.0  11.5    5.0   16    64       S
# 16    34.0  307.0  12.0    5.0   17    66       S
# 17     6.0   78.0  18.4    5.0   18    57       C
# 18    30.0  322.0  11.5    5.0   19    68      PS
# 19    11.0   44.0   9.7    5.0   20    62       S
# 20     1.0    8.0   9.7    5.0   21    59       S
# 21    11.0  320.0  16.6    5.0   22    73       C
# ...

# %%
157 - 111
# Out:
# 46

# %%
#treat

#fillna() [mean,median,mode]

# %%
pd.set_option('display.max_rows', None)

# %%
df.fillna(0)
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp Weather
# 0     41.0  190.0   7.4    2.0    1    67       S
# 1     36.0  118.0   8.0    5.0    2    72       C
# 2     12.0  149.0  12.6    5.0    3    74      PS
# 3     18.0  313.0  11.5    5.0    4    62       S
# 4      0.0    0.0  14.3    5.0    5    56       S
# 5     28.0    0.0  14.9    5.0    6    66       C
# 6     23.0  299.0   8.6    5.0    7    65      PS
# 7     19.0   99.0  13.8    5.0    8    59       C
# 8      8.0   19.0  20.1    5.0    9    61      PS
# 9      0.0  194.0   8.6    5.0   10    69       S
# 10     7.0    0.0   6.9    5.0   11    74       C
# 11    16.0  256.0   9.7    5.0   12    69      PS
# 12    11.0  290.0   9.2    5.0   13    66       S
# 13    14.0  274.0  10.9    5.0   14    68       S
# 14    18.0   65.0  13.2    5.0   15    58       C
# 15    14.0  334.0  11.5    5.0   16    64       S
# 16    34.0  307.0  12.0    5.0   17    66       S
# 17     6.0   78.0  18.4    5.0   18    57       C
# ...

# %%
df['Ozone'].median()
# Out:
# 31.0

# %%
df['Ozone'] = df['Ozone'].fillna(df['Ozone'].median())

# %%
df['Solar'] = df['Solar'].fillna(df['Solar'].mean())

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# Ozone      0.000000
# Solar      0.000000
# Wind       0.000000
# Month      0.636943
# Day        0.000000
# Temp       0.000000
# Weather    1.910828
# dtype: float64

# %%
# bfill ffill and mode method

# %%
df['Weather'].mode()[0]
# Out:
# 'S'

# %%
df['Weather'].fillna(df['Weather'].mode()[0])
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
# 5       C
# 6      PS
# 7       C
# 8      PS
# 9       S
# 10      C
# 11     PS
# 12      S
# 13      S
# 14      C
# 15      S
# 16      S
# 17      C
# 18     PS
# 19      S
# 20      S
# 21      C
# 22     PS
# 23      C
# 24     PS
# 25      C
# 26     PS
# 27      S
# 28      S
# 29      C
# 30     PS
# 31      S
# 32      C
# 33     PS
# 34      C
# 35     PS
# 36      C
# 37     PS
# 38      S
# 39      S
# 40      S
# 41      C
# 42     PS
# 43      S
# 44      S
# 45      C
# 46     PS
# 47      C
# 48     PS
# 49      S
# 50      S
# 51      S
# 52      C
# 53     PS
# 54      S
# 55      C
# 56     PS
# 57      C
# 58     PS
# 59      S
# 60      S
# 61      S
# 62      C
# 63     PS
# 64      S
# 65      S
# 66      C
# 67      C
# 68     PS
# 69      C
# 70     PS
# 71      S
# 72      S
# 73      S
# 74      C
# 75     PS
# 76      S
# 77      S
# 78      C
# 79     PS
# 80      C
# 81      S
# 82      S
# ...

# %%
df['Weather'].fillna(method = 'bfill')
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
# 5       C
# 6      PS
# 7       C
# 8      PS
# 9       S
# 10      C
# 11     PS
# 12      S
# 13      S
# 14      C
# 15      S
# 16      S
# 17      C
# 18     PS
# 19      S
# 20      S
# 21      C
# 22     PS
# 23      C
# 24     PS
# 25      C
# 26     PS
# 27      S
# 28      S
# 29      C
# 30     PS
# 31      S
# 32      C
# 33     PS
# 34      C
# 35     PS
# 36      C
# 37     PS
# 38      S
# 39      S
# 40      S
# 41      C
# 42     PS
# 43      S
# 44      S
# 45      C
# 46     PS
# 47      C
# 48     PS
# 49      S
# 50      S
# 51      S
# 52      C
# 53     PS
# 54      S
# 55      C
# 56     PS
# 57      C
# 58     PS
# 59      S
# 60      S
# 61      S
# 62      C
# 63     PS
# 64      S
# 65      S
# 66      C
# 67      C
# 68     PS
# 69      C
# 70     PS
# 71      S
# 72      S
# 73      S
# 74      C
# 75     PS
# 76      S
# 77      S
# 78      C
# 79     PS
# 80      C
# 81      S
# 82      S
# ...

# %%
df['Weather'].fillna(method = 'ffill',inplace = True)

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# Ozone      0.000000
# Solar      0.000000
# Wind       0.000000
# Month      0.636943
# Day        0.000000
# Temp       0.000000
# Weather    0.000000
# dtype: float64

# %%
# Data transformation techniques
# 1)Reduce skewness (sqrt/log)
# 2)Scaling (Normalization/standardization)
# 3)Encoding (Label Encoding/One hot encoding)

# %% [markdown]
# # Skewness treatment

# %%
sns.histplot(df.Ozone,kde = True)
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Count'>

# %%
df.Ozone
# Out:
# 0       41.0
# 1       36.0
# 2       12.0
# 3       18.0
# 4       31.0
# 5       28.0
# 6       23.0
# 7       19.0
# 8        8.0
# 9       31.0
# 10       7.0
# 11      16.0
# 12      11.0
# 13      14.0
# 14      18.0
# 15      14.0
# 16      34.0
# 17       6.0
# 18      30.0
# 19      11.0
# 20       1.0
# 21      11.0
# 22       4.0
# 23      32.0
# 24      31.0
# 25      31.0
# 26      31.0
# 27      23.0
# 28      45.0
# 29     115.0
# 30      37.0
# 31      31.0
# 32      31.0
# 33      31.0
# 34      31.0
# 35      31.0
# 36      31.0
# 37      29.0
# 38      31.0
# 39      71.0
# 40      39.0
# 41      31.0
# 42      31.0
# 43      23.0
# 44      31.0
# 45      31.0
# 46      21.0
# 47      37.0
# 48      20.0
# 49      12.0
# 50      13.0
# 51      31.0
# 52      31.0
# 53      31.0
# 54      31.0
# 55      31.0
# 56      31.0
# 57      31.0
# 58      31.0
# 59      31.0
# 60      31.0
# 61     135.0
# 62      49.0
# 63      32.0
# 64      31.0
# 65      64.0
# ...

# %%
np.sqrt(df.Ozone)
# Out:
# 0       6.403124
# 1       6.000000
# 2       3.464102
# 3       4.242641
# 4       5.567764
# 5       5.291503
# 6       4.795832
# 7       4.358899
# 8       2.828427
# 9       5.567764
# 10      2.645751
# 11      4.000000
# 12      3.316625
# 13      3.741657
# 14      4.242641
# 15      3.741657
# 16      5.830952
# 17      2.449490
# 18      5.477226
# 19      3.316625
# 20      1.000000
# 21      3.316625
# 22      2.000000
# 23      5.656854
# 24      5.567764
# 25      5.567764
# 26      5.567764
# 27      4.795832
# 28      6.708204
# 29     10.723805
# 30      6.082763
# 31      5.567764
# 32      5.567764
# 33      5.567764
# 34      5.567764
# 35      5.567764
# 36      5.567764
# 37      5.385165
# 38      5.567764
# 39      8.426150
# 40      6.244998
# 41      5.567764
# 42      5.567764
# 43      4.795832
# 44      5.567764
# 45      5.567764
# 46      4.582576
# 47      6.082763
# 48      4.472136
# 49      3.464102
# 50      3.605551
# 51      5.567764
# ...

# %%
sns.histplot(np.sqrt(df.Ozone),kde = True)
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Count'>

# %%
np.log10(100)
# Out:
# 2.0

# %%
np.log10(df.Ozone)
# Out:
# 0      1.612784
# 1      1.556303
# 2      1.079181
# 3      1.255273
# 4      1.491362
# 5      1.447158
# 6      1.361728
# 7      1.278754
# 8      0.903090
# 9      1.491362
# 10     0.845098
# 11     1.204120
# 12     1.041393
# 13     1.146128
# 14     1.255273
# 15     1.146128
# 16     1.531479
# 17     0.778151
# 18     1.477121
# 19     1.041393
# 20     0.000000
# 21     1.041393
# 22     0.602060
# 23     1.505150
# 24     1.491362
# 25     1.491362
# 26     1.491362
# 27     1.361728
# 28     1.653213
# 29     2.060698
# 30     1.568202
# 31     1.491362
# 32     1.491362
# 33     1.491362
# 34     1.491362
# 35     1.491362
# 36     1.491362
# 37     1.462398
# 38     1.491362
# 39     1.851258
# 40     1.591065
# 41     1.491362
# 42     1.491362
# 43     1.361728
# 44     1.491362
# 45     1.491362
# 46     1.322219
# 47     1.568202
# 48     1.301030
# 49     1.079181
# 50     1.113943
# 51     1.491362
# 52     1.491362
# 53     1.491362
# 54     1.491362
# ...

# %%
sns.histplot(np.log10(df.Ozone),kde = True)
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Count'>

# %% [markdown]
# # Scaling

# %% [markdown]
# ### normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df_scaled = df.drop('Weather',axis = 1)

# %%
df_scaled
# Out:
#      Ozone       Solar  Wind  Month  Day  Temp
# 0     41.0  190.000000   7.4    2.0    1    67
# 1     36.0  118.000000   8.0    5.0    2    72
# 2     12.0  149.000000  12.6    5.0    3    74
# 3     18.0  313.000000  11.5    5.0    4    62
# 4     31.0  185.366667  14.3    5.0    5    56
# 5     28.0  185.366667  14.9    5.0    6    66
# 6     23.0  299.000000   8.6    5.0    7    65
# 7     19.0   99.000000  13.8    5.0    8    59
# 8      8.0   19.000000  20.1    5.0    9    61
# 9     31.0  194.000000   8.6    5.0   10    69
# 10     7.0  185.366667   6.9    5.0   11    74
# 11    16.0  256.000000   9.7    5.0   12    69
# 12    11.0  290.000000   9.2    5.0   13    66
# 13    14.0  274.000000  10.9    5.0   14    68
# 14    18.0   65.000000  13.2    5.0   15    58
# 15    14.0  334.000000  11.5    5.0   16    64
# 16    34.0  307.000000  12.0    5.0   17    66
# 17     6.0   78.000000  18.4    5.0   18    57
# 18    30.0  322.000000  11.5    5.0   19    68
# ...

# %%
scaler.fit(df_scaled)
# Out:
# MinMaxScaler()

# %%
scaler.transform(df_scaled)
# Out:
# array([[0.23952096, 0.55963303, 0.3       , 0.        , 0.        ,
#         0.26829268],
#        [0.20958084, 0.33944954, 0.33157895, 0.42857143, 0.03333333,
#         0.3902439 ],
#        [0.06586826, 0.43425076, 0.57368421, 0.42857143, 0.06666667,
#         0.43902439],
#        [0.10179641, 0.93577982, 0.51578947, 0.42857143, 0.1       ,
#         0.14634146],
#        [0.17964072, 0.54546381, 0.66315789, 0.42857143, 0.13333333,
#         0.        ],
#        [0.16167665, 0.54546381, 0.69473684, 0.42857143, 0.16666667,
#         0.24390244],
#        [0.13173653, 0.89296636, 0.36315789, 0.42857143, 0.2       ,
#         0.2195122 ],
#        [0.10778443, 0.28134557, 0.63684211, 0.42857143, 0.23333333,
#         0.07317073],
#        [0.04191617, 0.03669725, 0.96842105, 0.42857143, 0.26666667,
#         0.12195122],
#        [0.17964072, 0.57186544, 0.36315789, 0.42857143, 0.3       ,
#         0.31707317],
#        [0.03592814, 0.54546381, 0.27368421, 0.42857143, 0.33333333,
# ...

# %%
max1 = df_scaled['Ozone'].max()

# %%
min1 = df_scaled['Ozone'].min()

# %%
X_scaled  = (41 - 1)/(168 - 1) # normalization formula

# %%
X_scaled
# Out:
# 0.23952095808383234

# %%
scaler.fit_transform(df_scaled)
# Out:
# array([[0.23952096, 0.55963303, 0.3       , 0.        , 0.        ,
#         0.26829268],
#        [0.20958084, 0.33944954, 0.33157895, 0.42857143, 0.03333333,
#         0.3902439 ],
#        [0.06586826, 0.43425076, 0.57368421, 0.42857143, 0.06666667,
#         0.43902439],
#        [0.10179641, 0.93577982, 0.51578947, 0.42857143, 0.1       ,
#         0.14634146],
#        [0.17964072, 0.54546381, 0.66315789, 0.42857143, 0.13333333,
#         0.        ],
#        [0.16167665, 0.54546381, 0.69473684, 0.42857143, 0.16666667,
#         0.24390244],
#        [0.13173653, 0.89296636, 0.36315789, 0.42857143, 0.2       ,
#         0.2195122 ],
#        [0.10778443, 0.28134557, 0.63684211, 0.42857143, 0.23333333,
#         0.07317073],
#        [0.04191617, 0.03669725, 0.96842105, 0.42857143, 0.26666667,
#         0.12195122],
#        [0.17964072, 0.57186544, 0.36315789, 0.42857143, 0.3       ,
#         0.31707317],
#        [0.03592814, 0.54546381, 0.27368421, 0.42857143, 0.33333333,
# ...

# %% [markdown]
# ### standard scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(df_scaled)
# Out:
# array([[ 0.06282803,  0.05342774, -0.72407878, -3.40567011, -1.66893666,
#         -1.14611638],
#        [-0.11144761, -0.7768163 , -0.55235617, -1.36749414, -1.55715208,
#         -0.612802  ],
#        [-0.94797067, -0.41935011,  0.76418385, -1.36749414, -1.4453675 ,
#         -0.39947625],
#        [-0.7388399 ,  1.47176131,  0.44935906, -1.36749414, -1.33358292,
#         -1.67943076],
#        [-0.28572324,  0.        ,  1.25073125, -1.36749414, -1.22179834,
#         -2.31940802],
#        [-0.39028863,  0.        ,  1.42245386, -1.36749414, -1.11001376,
#         -1.25277926],
#        [-0.56456426,  1.31032497, -0.38063356, -1.36749414, -0.99822918,
#         -1.35944213],
#        [-0.70398477, -0.99590848,  1.10762907, -1.36749414, -0.8864446 ,
#         -1.99941939],
#        [-1.08739118, -1.91840185,  2.91071649, -1.36749414, -0.77466002,
#         -1.78609364],
#        [-0.28572324,  0.09955241, -0.38063356, -1.36749414, -0.66287544,
#         -0.93279063],
# ...

# %%
(41 - df_scaled['Ozone'].mean())/df_scaled['Ozone'].std() # formula for std scaling
# Out:
# 0.06262762366104496

# %% [markdown]
# # Encoding

# %%
# converts categorical col to numerical

# %% [markdown]
# ### 1. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
L_E = LabelEncoder()

# %%
df['Weather_label'] = L_E.fit_transform(df['Weather'])

# %%
df.head(10)
# Out:
#    Ozone       Solar  Wind  Month  Day  Temp Weather  Weather_label
# 0   41.0  190.000000   7.4    2.0    1    67       S              2
# 1   36.0  118.000000   8.0    5.0    2    72       C              0
# 2   12.0  149.000000  12.6    5.0    3    74      PS              1
# 3   18.0  313.000000  11.5    5.0    4    62       S              2
# 4   31.0  185.366667  14.3    5.0    5    56       S              2
# 5   28.0  185.366667  14.9    5.0    6    66       C              0
# 6   23.0  299.000000   8.6    5.0    7    65      PS              1
# 7   19.0   99.000000  13.8    5.0    8    59       C              0
# 8    8.0   19.000000  20.1    5.0    9    61      PS              1
# 9   31.0  194.000000   8.6    5.0   10    69       S              2

# %%
pd.get_dummies(data = df,columns = ['Weather'])
# Out:
#      Ozone       Solar  Wind  Month  Day  Temp  Weather_label  Weather_C  \
# 0     41.0  190.000000   7.4    2.0    1    67              2          0
# 1     36.0  118.000000   8.0    5.0    2    72              0          1
# 2     12.0  149.000000  12.6    5.0    3    74              1          0
# 3     18.0  313.000000  11.5    5.0    4    62              2          0
# 4     31.0  185.366667  14.3    5.0    5    56              2          0
# 5     28.0  185.366667  14.9    5.0    6    66              0          1
# 6     23.0  299.000000   8.6    5.0    7    65              1          0
# 7     19.0   99.000000  13.8    5.0    8    59              0          1
# 8      8.0   19.000000  20.1    5.0    9    61              1          0
# 9     31.0  194.000000   8.6    5.0   10    69              2          0
# 10     7.0  185.366667   6.9    5.0   11    74              0          1
# 11    16.0  256.000000   9.7    5.0   12    69              1          0
# ...
