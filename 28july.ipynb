# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import math

# %%
df = pd.read_csv(r"C:\Users\manas\Desktop\ExclerDS_7pm\data_clean.csv",index_col =0)

# %%
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     2    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df.shape
# Out:
# (158, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
df['Temp C']=pd.to_numeric(df['Temp C'],errors = 'coerce')

# %%
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     2    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df['Month']=pd.to_numeric(df['Month'],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 12.3+ KB

# %%
df.describe()
# Out:
#             Ozone     Solar.R        Wind      Temp C       Month         Day  \
# count  120.000000  151.000000  158.000000  157.000000  157.000000  158.000000
# mean    41.583333  185.403974    9.957595   77.751592    7.025478   16.006329
# std     32.620709   88.723103    3.511261    9.403120    1.480424    8.997166
# min      1.000000    7.000000    1.700000   56.000000    2.000000    1.000000
# 25%     18.000000  119.000000    7.400000   72.000000    6.000000    8.000000
# 50%     30.500000  197.000000    9.700000   79.000000    7.000000   16.000000
# 75%     61.500000  257.000000   11.875000   84.000000    8.000000   24.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000
#
#          Year        Temp
# count   158.0  158.000000
# mean   2010.0   77.727848
# std       0.0    9.377877
# min    2010.0   56.000000
# 25%    2010.0   72.000000
# 50%    2010.0   78.500000
# 75%    2010.0   84.000000
# max    2010.0   97.000000

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      1
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.drop('Year',axis =1,inplace = True)

# %%
df.drop('Day',axis =1,inplace = True)

# %%
df.drop('Temp C',axis =1,inplace = True)

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 1     41.0    190.0   7.4    2.0    67       S
# 2     36.0    118.0   8.0    5.0    72       C
# 3     12.0    149.0  12.6    5.0    74      PS
# 4     18.0    313.0  11.5    5.0    62       S
# 5      NaN      NaN  14.3    5.0    56       S
# ..     ...      ...   ...    ...   ...     ...
# 154   41.0    190.0   7.4    5.0    67       C
# 155   30.0    193.0   6.9    9.0    70      PS
# 156    NaN    145.0  13.2    9.0    77       S
# 157   14.0    191.0  14.3    9.0    75       S
# 158   18.0    131.0   8.0    9.0    76       C
#
# [158 rows x 6 columns]

# %%
df[df.duplicated()]  # To see the duplicate values.
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 157   14.0    191.0  14.3    9.0    75       S

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Month, Temp, Weather]
# Index: []

# %% [markdown]
# # Removing outliers from data.

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 1     41.0    190.0   7.4    2.0    67       S
# 2     36.0    118.0   8.0    5.0    72       C
# 3     12.0    149.0  12.6    5.0    74      PS
# 4     18.0    313.0  11.5    5.0    62       S
# 5      NaN      NaN  14.3    5.0    56       S
# ..     ...      ...   ...    ...   ...     ...
# 153   20.0    223.0  11.5    9.0    68       S
# 154   41.0    190.0   7.4    5.0    67       C
# 155   30.0    193.0   6.9    9.0    70      PS
# 156    NaN    145.0  13.2    9.0    77       S
# 158   18.0    131.0   8.0    9.0    76       C
#
# [157 rows x 6 columns]

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['Ozone'])
# Out:
# <Axes: ylabel='Ozone'>

# %%
df[df['Ozone']>125]
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 62   135.0    269.0   4.1    7.0    84       S
# 117  168.0    238.0   3.4    8.0    81      PS

# %%
df['Ozone'].fillna(df['Ozone'].median(),inplace = True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_12948\2491320245.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ozone'].fillna(df['Ozone'].median(),inplace = True)

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 1     41.0    190.0   7.4    2.0    67       S
# 2     36.0    118.0   8.0    5.0    72       C
# 3     12.0    149.0  12.6    5.0    74      PS
# 4     18.0    313.0  11.5    5.0    62       S
# 5     31.0      NaN  14.3    5.0    56       S
# ..     ...      ...   ...    ...   ...     ...
# 153   20.0    223.0  11.5    9.0    68       S
# 154   41.0    190.0   7.4    5.0    67       C
# 155   30.0    193.0   6.9    9.0    70      PS
# 156   31.0    145.0  13.2    9.0    77       S
# 158   18.0    131.0   8.0    9.0    76       C
#
# [157 rows x 6 columns]

# %%
df['Ozone'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 1 to 158
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar.R  150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Temp     157 non-null    int64
#  5   Weather  154 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.6+ KB

# %%
sns.boxplot(df['Solar.R'])
# Out:
# <Axes: ylabel='Solar.R'>

# %%
sns.boxplot(df['Wind'])
# Out:
# <Axes: ylabel='Wind'>

# %%
df['Wind'][df['Wind']>16.0]
# Out:
# 9      20.1
# 18     18.4
# 22     16.6
# 25     16.6
# 34     16.1
# 48     20.7
# 148    16.6
# Name: Wind, dtype: float64

# %%
sns.boxplot(df['Wind'])
# Out:
# <Axes: ylabel='Wind'>

# %%
from scipy.stats.mstats import winsorize

# %%
array = winsorize(df.Wind.dropna(),(0.05,0.05))

# %%
sns.histplot(array,kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Temp Weather
# 1     41.0    190.0   7.4    2.0    67       S
# 2     36.0    118.0   8.0    5.0    72       C
# 3     12.0    149.0  12.6    5.0    74      PS
# 4     18.0    313.0  11.5    5.0    62       S
# 5     31.0    199.0  14.3    5.0    56       S
# ..     ...      ...   ...    ...   ...     ...
# 153   20.0    223.0  11.5    9.0    68       S
# 154   41.0    190.0   7.4    5.0    67       C
# 155   30.0    193.0   6.9    9.0    70      PS
# 156   31.0    145.0  13.2    9.0    77       S
# 158   18.0    131.0   8.0    9.0    76       C
#
# [157 rows x 6 columns]

# %%
sns.heatmap(df.isnull(),cmap  =sns.color_palette(palette = 'BuGn'))
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
L_E  =LabelEncoder()
df['Weather']=L_E.fit_transform(df['Weather'])

# %%
df['Weather']
# Out:
# 1      2
# 2      0
# 3      1
# 4      2
# 5      2
#       ..
# 153    2
# 154    0
# 155    1
# 156    2
# 158    0
# Name: Weather, Length: 157, dtype: int32

# %%
sns.heatmap(df.isnull(),cmap  =sns.color_palette(palette = 'BuGn'))
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      1
# Temp       0
# Weather    0
# dtype: int64

# %%
df['Ozone'].median()
# Out:
# 31.0
