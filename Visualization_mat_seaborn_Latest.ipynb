# %%
#install and then import matplotlib
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)

# %%
# matplotlib to render plots in the notebook
# %matplotlib inline

# %%
plt.show()

# %%
x = -3, 5, 7

# %%
x
# Out:
# (-3, 5, 7)

# %%
x[0]
# Out:
# -3

# %%
x
# Out:
# (-3, 5, 7)

# %%
x = [-3, 5, 7]

# %%
x
# Out:
# [-3, 5, 7]

# %%
y = [10, 2, 5]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y,'bo')

# %%
plt.plot(y,'r+',markersize=18)

# %%
fig = plt.figure(figsize=(14,8))

plt.plot(x, y)

plt.xlim(-5, 10)

plt.ylim(-3, 12)

plt.xlabel('X Axis')
plt.ylabel('Y axis')

plt.title('Line Plot',size=12)
plt.suptitle('Sales Comaprison', size=12);

# %%
fig.savefig('example1.png')

# %%
fig

# %%
plt.plot(figsize = (12,8))
# Out:
# []

# %%
plt.subplots(figsize = (12,8))
plt.show()

# %%
fig,axes = plt.subplots(nrows=2, ncols=3,figsize = (12,8))

# %%
fig

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig = plt.subplots(nrows=3, ncols=1)

# %%
fig

# %%
# More than one Axes with plt.subplots, then the second item in the tuple is a NumPy array containing all the Axes

fig,axes = plt.subplots(2, 4,figsize=(15,8))

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# #### Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mtcars = pd.read_csv("D:\\Excelr lecs\\lec 3\\mtcars.csv")

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
# table 
pd.crosstab(mtcars['gear'],mtcars['cyl'])
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
#

# %%
# bar plot between 2 different categories 
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gear'>

# %%
mtcars["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
plt.bar(mtcars["gear"].value_counts().index,mtcars["gear"].value_counts().values)
# Out:
# <BarContainer object of 3 artists>

# %%
# there are a lot of 3 gear cars with 8cylinders
# there are very few 5 gear cars
# there is no 8 cylinder in 4 gear cars

# %%
mtcars["gear"].count()
# Out:
# 32

# %%
mtcars["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
#fig2 = plt.figure()
#mtcars["gear"].value_counts()
mtcars.gear.value_counts().plot(kind="pie")
#fig2.savefig('pie.png', dpi=300, bbox_inches='tight')
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
plt.pie(mtcars.gear.value_counts(),labels = ['3','4','5'],autopct='%.2f%%',explode=[0, 0, 0.1])
plt.show()

# %%
# %matplotlib inline

# %%
# %matplotlib notebook

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)
plt.xlabel('mpg', fontdict={'fontsize':16})
plt.ylabel('qsec',fontdict={'fontsize':16})
# Out:
# Text(0, 0.5, 'qsec')

# %%
mtcars.corr()['mpg']['qsec']
# Out:
# 0.41868403392177816

# %%
mtcars.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %% [markdown]
# ##

# %%
import seaborn as sns

# %%
sns.pairplot(mtcars)

# %%
plt.scatter(mtcars.wt,mtcars.mpg)## scatter plot of two variables
plt.xlabel('wt')
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %%
mtcars.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
plt.hist(mtcars.mpg)
plt.show()

# %%
# Graphical Representation of data
# import matplotlib.pyplot as plt
# Histogram
plt.hist(mtcars['mpg'],edgecolor ="black",color = '#d9004c')
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars['cyl'])
plt.show()

# %%
mtcars['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
mtcars['mpg'].skew()
# Out:
# 0.6723771376290805

# %%
mtcars.skew()
# Out:
# mpg     0.672377
# cyl    -0.192261
# disp    0.420233
# hp      0.799407
# drat    0.292780
# wt      0.465916
# qsec    0.406347
# vs      0.264542
# am      0.400809
# gear    0.582309
# carb    1.157091
# dtype: float64

# %%
plt.hist(mtcars['carb'])
plt.show()

# %%
mtcars.mpg.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
warnings.filterwarnings('ignore', 'DeprecationWarning')

# %%
plt.hist(mtcars['mpg'],facecolor ="peru",edgecolor ="blue",bins =8)

#creates histogram with 5bins and colours filled init.
# Out:
# (array([3., 7., 7., 6., 3., 2., 2., 2.]),
#  array([10.4   , 13.3375, 16.275 , 19.2125, 22.15  , 25.0875, 28.025 ,
#         30.9625, 33.9   ]),
#  <BarContainer object of 8 artists>)

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
plt.boxplot(mtcars.mpg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10e5ec69ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10e5ec751c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10e5ec69730>],
#  'medians': [<matplotlib.lines.Line2D at 0x10e5ec758e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10e5ec75c70>],
#  'means': []}

# %%
#Boxplot
#help(plt.boxplot)
bp = plt.boxplot(mtcars.mpg)

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
1.5*(22.8 - 15.425)+22.8
# Out:
# 33.8625

# %%
l1 = [1,2,3,4]

# %%
for i in l1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
l1 = [1,2,3,4]

# %%
l1.append(5)

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
for x in bp['fliers']:
    print(x.get_ydata())
# Out:
# [33.9]

# %%
[x.get_ydata() for x in bp['fliers']]
# Out:
# [array([33.9])]

# %%
plt.boxplot(mtcars['mpg'],vert =False);
plt.ylabel("MPG");plt.xlabel("Boxplot");plt.title("Boxplot"); # for vertical

# %%
#Violin Plot
#help(plt.violinplot)
fig, ax = plt.subplots()
ax.violinplot(mtcars["mpg"])
ax.boxplot(mtcars['mpg'],vert = True,boxprops = dict(edgecolor = "blue"),whiskerprops = dict(color = "blue"),capprops = dict(color = "blue"),meanline=True,
    showmeans=True,patch_artist = True)
plt.show()

# %%
mtcars['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
mtcars['mpg'].std()
# Out:
# 6.026948052089105

# %% [markdown]
# # seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\iftekar\anaconda3\lib\site-packages)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.load_dataset

# %%
tips =sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_csv('D:\\Excelr lecs\\tips.csv')

# %%
pd.read_csv('tips.csv',index_col=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.groupby('day')['tip'].sum().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
plt.bar(tips.day,tips.tip)
# Out:
# <BarContainer object of 244 artists>

# %%
tips.groupby('day')['tip'].sum().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette(palette='Greens')
# Out:
# [(0.8828143021914648, 0.9546943483275664, 0.8621914648212226),
#  (0.7371472510572856, 0.895517108804306, 0.7108342945021145),
#  (0.5573241061130334, 0.8164244521337947, 0.546958861976163),
#  (0.3388235294117647, 0.7117262591311034, 0.40584390618992694),
#  (0.17139561707035755, 0.581514801999231, 0.2979008073817762),
#  (0.017762399077277974, 0.44267589388696654, 0.18523644752018453)]

# %%
sns.barplot(x = 'day',y = 'tip',data = tips,estimator=sum,palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x = 'day',y = 'tip',data = tips, estimator = sum,palette='pastel') #
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.set_palette("bright")

# %%
sns.barplot(x = 'day',y = 'tip',data = tips,estimator = sum,ci = None)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_csv('tips.csv')

# %% [markdown]
# ## Univariate → “one variable” data visualization

# %%
sns.set_style("whitegrid")

# %%
#strip plot

sns.stripplot(y= 'tip', data=tips,jitter = True)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.histplot(tips, x = 'tip')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.stripplot(data = tips,x = 'day', y = 'tip')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
tips['tip'].mode()
# Out:
# 0    2.0
# Name: tip, dtype: float64

# %%
#Grouping with stripplot()
sns.stripplot(x='day', y='tip',hue = 'day',data=tips,order=['Sun','Sat','Fri','Thur'])
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x='day', y='tip',hue = 'sex', data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x='day', y='tip', data=tips, size=5,jitter=False)
plt.ylabel('tip ($)')
plt.show()

# %%
#Swarm plot

# import warnings
# warnings.filterwarnings('ignore')



sns.swarmplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips['tip'].mode()
# Out:
# 0    2.0
# Name: tip, dtype: float64

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')
plt.ylabel('tip ($)')
plt.show()

# %%
#Changing orientation
plt.figure(figsize=(10,6))
sns.swarmplot(x='tip', y='day', data=tips, hue='sex',orient='h')
plt.xlabel('tip ($)')
plt.show()

# %%
tips[tips['day'] == 'Thur']['sex'].value_counts()
# Out:
# Female    32
# Male      30
# Name: sex, dtype: int64

# %% [markdown]
# ### Box and Violin plot

# %%
sns.boxplot(data = tips,y = 'tip',orient = 'h')
# Out:
# C:\Users\Iftekar\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# <AxesSubplot:ylabel='tip'>

# %%
#plt.subplot(1,2,1)
sns.boxplot(data = tips,x = 'day',y = 'tip')
plt.ylabel('tip ($)')
# Out:
# Text(0, 0.5, 'tip ($)')

# %%
#plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.subplot(1,2,1)
sns.boxplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')

plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')

plt.show()

# %%
##Combining plots

sns.violinplot(x='day', y='tip', data=tips,inner = None, color='lightgray')
sns.stripplot(x='day', y='tip', data=tips,hue = 'day', size=4,jitter=True)
plt.ylabel('tip ($)')
plt.show()

# %%
tips[tips['day']=='Fri']['tip'].kurt()
# Out:
# -0.5958454814843184

# %%
tips[tips['day']=='Thur']['tip'].kurt()
# Out:
# 0.8022916929739381

# %% [markdown]
# ## Bivariate → “two variables” data visualization

# %%
#Joint plot

sns.jointplot(x= 'total_bill', y= 'tip', data=tips)
plt.show()

# %%
# Density plot
sns.jointplot(x='total_bill', y= 'tip', data=tips, kind='kde')
plt.show()

# %%
#Pair plot

sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %%
g = sns.FacetGrid(tips,col = 'time',row = 'sex',hue = 'sex')
g.map(sns.scatterplot,"total_bill", "tip")

# %%
g.map(sns.scatterplot,"total_bill", "tip")

# %% [markdown]
# # Titanic data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.to_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data = pd.read_csv("train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #survival - Survival (0 = No; 1 = Yes)
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# name - Name
# sex - Sex
# age - Age
# sibsp - Number of Siblings/Spouses Aboard
# parch - Number of Parents/Children Aboard
# ticket - Ticket Number
# fare - Passenger Fare
# cabin - Cabin
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# ### Data types

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Proportion of target (Survived)

# %%
data.groupby('Survived')['PassengerId']

# %%
data.groupby('Survived')['PassengerId'].count().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='PassengerId'>

# %%
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Visual Exploration

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='Survived', y="Age", data=data);

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#f, ax = plt.subplots(figsize=(10,8))
sns.barplot(x='Sex', y="Survived",  data=data);

# %%
data.groupby('Sex').Survived.mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=data);

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %%
sns.barplot(x="Pclass", y="Survived", hue='Sex',data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %%
data.loc[data['Survived']==1,"Age"].dropna()
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 290, dtype: float64

# %%
data[data['Survived']==1]['Age'].dropna()
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 290, dtype: float64

# %%
data.loc[data['Survived']==1,'Age'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.loc[data['Survived']==1,'Age'].isnull().sum()
#
# NameError: name 'data' is not defined

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data[data['Survived']==1]['Age'].dropna()
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 290, dtype: float64

# %%
plt.hist()

# %%
sns.distplot(data[data['Survived']==1]['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
data1 = data[data['Survived']==1]['Age'].dropna()

# %%
data1
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 290, dtype: float64

# %%
sns.distplot(data1,hist_kws={"histtype": "bar", "linewidth": 1,"color": '#fa8072',"edgecolor":"black"})
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
survived = data.loc[data['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");

# %%
data.loc[data['Survived']==0,"Age"]
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
not_survived = data.loc[data['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
plt.title("Not Survived");

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.pairplot(data.dropna());

# %%
grid1 = sns.FacetGrid(data, col='Survived', row = 'Sex', aspect=2)
grid1.map(plt.hist, 'Age', bins=20)

# %%
grid1 = sns.FacetGrid(data, col='Survived', aspect=2)
grid1.map(plt.hist, 'Age',alpha = 0.5, bins=20)
grid1.add_legend()

# %%
# Pclass vs Survive
grid = sns.FacetGrid(data, col='Survived', row='Pclass', size=2.4, aspect=2)
grid.map(plt.hist, 'Age',alpha = 0.5, bins=20)
grid.add_legend()

# %%
grid

# %%
grid.map(plt.hist, 'Age', alpha = 0.8,bins=20)
grid.add_legend()

# %%
sns.barplot(x = 'Embarked',y = 'Survived',data = data,estimator=sum)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %%
data[data['Embarked']=='Q']['Pclass'].value_counts()
# Out:
# 3    72
# 2     3
# 1     2
# Name: Pclass, dtype: int64

# %%
data[data['Embarked']=='Q'].groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.750000
# male      0.073171
# Name: Survived, dtype: float64

# %%
sns.barplot(x = 'Sex' , y = 'Survived',data = data[data['Embarked']=='Q'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.distplot(data[data['Embarked'] == 'C']['Survived'],bins=3,kde=False)
# Out:
# C:\Users\Iftekar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Survived'>

# %%
data[data['Embarked'] == 'C']['Survived'].value_counts()
# Out:
# 1    93
# 0    75
# Name: Survived, dtype: int64

# %%
data[data['Embarked']=='Q']['Survived'].value_counts()
# Out:
# 0    47
# 1    30
# Name: Survived, dtype: int64

# %%
sns.distplot(a=data[data['Embarked']=='C']['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()

plt.title("QueensTown")
sns.distplot(a=data[data['Embarked']=='Q']['Survived'],bins=3,kde=False)
plt.xticks([0,1])
plt.show()

plt.title("Southampton")
sns.distplot(a=data[data['Embarked']=='S']['Survived'],bins=3,kde=False)
plt.xticks([0,1])
plt.show()
#Most of the Passengers embarked from Southampton

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
plt.show()

# %%
fig,axes = plt.subplots(2, 4,figsize=(16, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[0,0])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[0,1])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[0,2])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[0,3])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[1,0])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[1,1])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[1,2])
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[1,3])
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
data.groupby('Pclass')['Survived'].mean().plot(kind = 'barh',ax = axes[0,0])
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
data['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data.groupby('Pclass')

# %%
data[data['Pclass']== 1]['Survived'].value_counts()
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64

# %%
data[data['Pclass']== 1]['Survived'].value_counts()
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64

# %%
(136+80)
# Out:
# 216

# %%
136/216
# Out:
# 0.6296296296296297

# %%
data[data['Pclass']== 1]['Survived'].value_counts()
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64
